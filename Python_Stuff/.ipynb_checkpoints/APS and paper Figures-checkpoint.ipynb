# %%
import copy
import os
import numpy as np
import matplotlib.pyplot as plt
from pydmd import DMD
from pydmd.bopdmd import BOPDMD
from pydmd import DMDc
from scipy.signal import StateSpace, lsim
from scipy.io import loadmat,savemat
import pysindy as ps
import scipy
import pickle
import control as ct
from sklearn.metrics import mean_squared_error
import seaborn as sns
import pandas as pd

# %%
def bopdmd_train_test(svd_rank,num_trials,training_set,training_voltage,test_voltage,train_time,test_time,Btilde,return_training_fit, 
                     conjugate_bool, stable_bool, noise_level, evaluate,C,D):
    optdmd = BOPDMD(svd_rank = svd_rank, compute_A = True) #make our opt and bop objects with the correct
                                                            #number of trials and svd rank
        
        
    if conjugate_bool == True and stable_bool == True:
        bopdmd = BOPDMD(svd_rank = svd_rank, num_trials = num_trials, compute_A = True, eig_constraints = {'stable', 'conjugate_pairs'})
    elif conjugate_bool == True and stable_bool == False:
        bopdmd = BOPDMD(svd_rank = svd_rank, num_trials = num_trials, compute_A = True, eig_constraints = {'conjugate_pairs'})
    elif stable_bool == True and conjugate_bool == False:
        bopdmd = BOPDMD(svd_rank = svd_rank, num_trials = num_trials, compute_A = True, eig_constraints = {'stable'})
    else:
        bopdmd = BOPDMD(svd_rank = svd_rank, num_trials = num_trials, compute_A = True)
    
#     rmse = mean_squared_error(training_set[:, 1], np.zeros(training_set[:, 1].shape), squared=False)
    training_set_func = training_set + np.random.normal(0,  (np.sqrt(np.mean(training_set**2))/ 100.0) * noise_level, training_set.shape)
    bopdmd.fit(training_set_func,train_time) #fit out data
    
    Atilde = bopdmd.A #get A matrix from bop
    
    
    
    #now we are going to see how well bop does on our test voltages. These will simulate a vacuum shot and
    #be a series of 3 state square waves that are fed into each of the four circuits
    if evaluate == True:
        tout,yout,xout = lsim((Atilde,Btilde,C,D),test_voltage,test_time)
    
        return Atilde,bopdmd,xout
    else:
        return Atilde,bopdmd
    
    if return_training_fit == True:
        tout_train,yout_train,xout_train = lsim((Atilde,Btilde,C,D),train_voltage,time)
        return xout_train

# %%
def make_graph(data,title,legend,impulse,time,*args): #data should be a list of what one wants plotted,title is a string,
                                  #legend is an array of strings,impulse is a boolean if one is plotting the ringdown of a shot
    '''
    Function for making graphs of circuit data in a particular configuration and order
    data: list of arrays to be plotted on the graph
    title: string to be used as plot title
    legend: array of strings indicating each legend entry. 
    impulse: bool. Changes the x-axis scale if the data being plotted is the tail end of the shot
    time: array. Time vector used when plotting
    single_element: string either 'L1','C','L2' that will plot just a row of the desired element. else leave blank do 
    this when you have time

    '''


    fig, ax = plt.subplots(nrows=3, ncols=4, sharex=True, sharey = 'row', figsize=(20, 15))
    fig.tight_layout()
    fig.text(0.5, -0.04, 'Time (ms)', ha='center', fontsize = 28)
    fig.text(-0.04, 0.175, 'Flux Coil Current (A)', va='center', rotation='vertical', fontsize = 28)
    fig.text(-0.04, 0.5, 'Cap. Voltage (V)', va='center', rotation='vertical', fontsize = 28)
    fig.text(-0.04, 0.825, 'Series Coil Current (A)', va='center', rotation='vertical', fontsize = 28)
    fig.text(.5,1.04,title,ha = 'center',fontsize =35 )
    
    if impulse == False:
        plt.xlim([0,4])


    L1 = [0,3,6,9]
    C = [1,4,7,10]
    L2 = [2,5,8,11]
    
    colors = ['r','k','--b']
    alphas = [1,.65,1]
    for i in range(len(L1)):
        count = 0
        for j in data:
            plt.subplot(3,4,i+1)
            plt.plot(1000*time,np.real(j[:,L1[i]]),colors[count],alpha = alphas[count])
            count = count + 1
        plt.grid()


    for i in range(len(C)):
        count = 0
        for j in data:
            plt.subplot(3,4,i+5)
            plt.plot(1000*time,np.real(j[:,C[i]]),colors[count],alpha = alphas[count])
            count = count + 1
        plt.grid()

    for i in range(len(L2)):
        count = 0
        for j in data:
            plt.subplot(3,4,i+9)
            plt.plot(1000*time,np.real(j[:,L2[i]]),colors[count],alpha = alphas[count])
            count = count + 1
        plt.grid()


    plt.tight_layout(pad=.5)
    fig.legend(legend, fontsize = 25)

# %%
def make_row_graph(data,title,legend,impulse,time,*argv, plasma = None): #data should be a list of what one wants plotted,title is a string,
                                  #legend is an array of strings,impulse is a boolean if one is plotting the ringdown of a shot
    '''
    Function for making graphs of circuit data in a particular configuration and order
    data: list of arrays to be plotted on the graph
    title: string to be used as plot title
    legend: array of strings indicating each legend entry. 
    impulse: bool. Changes the x-axis scale if the data being plotted is the tail end of the shot
    time: array. Time vector used when plotting
    single_element: string either 'L1','C','L2' that will plot just a row of the desired element. else leave blank do 
    this when you have time
    plasma: boolean. If set to true, will add a blue line at x=1 ms to indicate where the system switches from vacuum to plasma
    '''
    
    

    fig, ax = plt.subplots(nrows=1, ncols=4, sharex=True, sharey = 'row', figsize=(18, 5))
    fig.tight_layout()
    fig.text(0.5, 0.04, 'Time (ms)', ha='center', fontsize = 25)
    fig.text(.5,1.04,title,ha = 'center',fontsize =35 )
    fig.subplots_adjust(wspace=0.1)
    if impulse == False:
        plt.xlim([0,4])


    L1 = [0,3,6,9]
    C = [1,4,7,10]
    L2 = [2,5,8,11]
    alphas = [1,.65,1]
    colors = ['r','k','--b']
    if argv[0] == 'L1':
        
        
        for i in range(len(L1)):
            count = 0
            for j in data:
                plt.subplot(1,4,i+1)
                if plasma == True:
                    plt.axvline(x=1, label = '_nolegend_', linewidth = 3)
                
                plt.plot(1000*time,np.real(j[:,L1[i]]),colors[count],alpha = alphas[count])
                plt.xticks(fontsize=17)
                plt.yticks(fontsize = 17)
                count = count + 1
            plt.grid()
        fig.text(0.02, 0.5, 'Series Coil Current (A)', va='center', rotation='vertical', fontsize = 23)
            
        
    if argv[0] == 'C':
        for i in range(len(C)):
            count = 0
            for j in data:
                plt.subplot(1,4,i+1)
                if plasma == True:
                    plt.axvline(x=1, label = '_nolegend_', linewidth = 3)
                plt.plot(1000*time,np.real(j[:,C[i]]),colors[count],alpha = alphas[count])
                plt.xticks(fontsize = 17)
                plt.yticks(fontsize = 17)
                count = count + 1
            plt.grid()
        fig.text(0.02, 0.5, 'Cap. Voltage (V)', va='center', rotation='vertical', fontsize = 23)
        
    if argv[0] == 'L2':
        
        for i in range(len(L2)):
            count = 0
            for j in data:
                plt.subplot(1,4,i+1)
                if plasma == True:
                    plt.axvline(x=1, label = '_nolegend_', linewidth = 3)
                plt.plot(1000*time,np.real(j[:,L2[i]]),colors[count],alpha = alphas[count])
                plt.xticks(fontsize=17)
                plt.yticks(fontsize = 17)
                count = count + 1
            plt.grid()
        fig.text(0.02, 0.5, 'Flux Coil Current (A)', va='center', rotation='vertical', fontsize = 23)



    fig.legend(legend, fontsize = 18,loc = 'upper right',bbox_to_anchor=(.945, .86), borderaxespad=0.0)

# %%
filename = 'data/continuous_vacuum_ss_model'
with open(filename,'rb') as file:
    sysc = pickle.load(file)
    print(f'object successfully saved to {filename}')
A = sysc.A #A matrix from vacuum model
B = sysc.B #B matrix from vacuum model
C = sysc.C #C matrix from vacuum model
D = sysc.D #D matrix from vacuum model

print(np.shape(D))

opt_A = loadmat('data/opt_A_matrix').get('afull')
bop_A_vacuum = loadmat('data/bop_A_matrix_vacuum').get('atilde_bop_no_conj')

bop_on_plasma = loadmat('data/bop_dmd_on_plasma_shot_220816009').get('xout_bop_avg')
# Out:
# object successfully saved to data/continuous_vacuum_ss_model
# (4, 4)

# %%
opt_A_sim = loadmat('data/opt_A_sim_matrix').get('afull')
bop_A_plasma = loadmat('data/bop_dmd_plasma_shot_220816009')
A_plasma = loadmat('data/plasma_ss_A_matrix').get('A')
bop_plasma_A_matrix = loadmat('data/bop_dmd_A_matrix_220816009_test').get('atilde_bop_no_conj')
bop_plasma_A_matrix_eig_variance = loadmat('data/bop_dmd_A_matrix_220816009_test_eigenvalue_variance').get('e_var')
print(bop_plasma_A_matrix)

B_13 = np.vstack((B,np.ones((1,4))));

C_13 = np.hstack((C,np.ones((4,1))))
# Out:
# [[ 6.73456812e+03+3.45521206e+00j -7.13254841e+03-2.50574677e-02j
#   -1.06819764e+04-1.10784290e+00j -4.37829501e+04-7.67343998e-01j
#   -1.55154680e+03-1.36633529e-01j  2.14229989e+04-1.52867345e+00j
#    1.68273474e+04+1.76320945e+00j  5.77444003e+03+1.14015458e-01j
#    1.65745475e+04-3.43438835e+00j  5.24687496e+04+9.70200249e-01j
#    4.43459262e+02+2.80604081e-01j -1.61747566e+04+9.35037562e-01j
#    4.36532794e+02+9.56847986e-03j]
#  [ 1.10712840e+04+3.24893489e-01j -1.34620161e+02-2.19487834e-03j
#   -3.55176387e+03-1.43918531e-01j -1.57310091e+03-1.05958077e-01j
#   -8.23828621e+02-1.69386836e-02j -3.32219069e+03-1.44783897e-01j
#   -1.83995588e+03+1.65724179e-01j  7.74379342e+01+1.98374160e-03j
#   -3.83682771e+03-3.15574847e-01j  1.99772539e+03+6.99880803e-02j
#    9.45127655e+02+3.05290445e-02j  2.24865122e+03+1.07837080e-01j
#   -6.24060875e+01+7.83496878e-04j]
#  [ 8.53808492e+03-4.15179724e-01j  2.28229395e+03-3.15031761e-02j
#    7.43794710e+02+2.42558355e-01j  1.72508452e+04+5.73373492e-01j
#   -8.21793106e+02-4.24002490e-02j -8.56596696e+03+4.80845255e-01j
#   -1.27787315e+04-2.07396655e-02j -2.75486929e+03-1.14831231e-01j
#   -6.26336969e+02+1.23849035e+00j -1.83265171e+04-1.31095219e-01j
#    7.30165140e+02-5.42010346e-02j  6.88509498e+03-2.81475031e-01j
#   -3.43795291e+02-1.81871126e-02j]
#  [ 6.78845059e+04+2.93305393e+00j -3.31988430e+02-6.61407975e-02j
#   -2.05145403e+04-9.60289132e-01j -4.92628539e+02-2.10634238e-01j
#   -6.01707819e+03-2.02882435e-01j -1.80581686e+04-9.36186890e-01j
#   -2.68702748e+04+1.78313908e+00j -1.34564844e+03-5.71336745e-02j
#   -6.88568591e+03-1.90251178e+00j  3.84647756e+03+7.60398276e-01j
#    5.80471153e+03+2.28493436e-01j  1.33928716e+04+6.58635580e-01j
#   -4.84756843e+02-1.67876068e-02j]
#  [ 4.84557788e+02-3.56179089e-01j  6.06342630e+02-1.59688611e-03j
#    1.14486803e+03+1.30144598e-01j  6.15158898e+03+1.50505753e-01j
#   -1.47669225e+02+1.08651491e-02j -1.63169977e+03+2.04141170e-01j
#   -7.02805983e+02-1.57495685e-01j -1.00323213e+03-1.83671803e-02j
#    6.13481436e+02+4.39970790e-01j -5.32098256e+03-9.78254663e-02j
#   -2.13077117e+01-3.24006271e-02j  1.40840637e+03-1.28387792e-01j
#   -1.25018634e+02-3.18334850e-03j]
#  [-4.41821686e+04-1.44591885e+00j  2.78322102e+03+2.78961452e-02j
#    1.27745282e+04+5.26474876e-01j  1.89634926e+03+9.04993596e-02j
#    5.02639510e+03+7.42776462e-02j  2.10117990e+03+3.85799548e-01j
#   -6.86087715e+03-7.03341954e-01j  1.51755301e+03-1.11280317e-02j
#   -6.91230448e+03+1.00441551e+00j -1.76573908e+04-3.42068780e-01j
#   -3.17683653e+03-1.14590458e-01j -1.96538310e+03-2.70827656e-01j
#    4.80476132e+02+3.06910044e-03j]
#  [-2.14158507e+04-3.81102566e+00j  3.73106459e+03-1.38870221e-01j
#    3.43568584e+04+2.18491235e+00j  1.34430546e+05+3.81179680e+00j
#   -7.91074510e+03+7.77239041e-02j  2.43210436e+04+3.60108399e+00j
#    2.73476185e+03-1.67053608e+00j -2.57555874e+04-2.35061285e-01j
#    1.28956736e+05+7.24204017e+00j -7.62400880e+04-7.29609939e-01j
#   -4.66526693e+03-4.78064236e-01j -7.30934716e+03-2.54940887e+00j
#   -2.74590970e+03-8.99477615e-02j]
#  [-1.03633939e+04-4.97302967e-01j  2.13476203e+02+4.33937456e-03j
#    3.33262717e+03+1.83630747e-01j  1.10274269e+03+1.30550469e-01j
#    9.36341331e+02+2.22385052e-02j  2.23951832e+03+2.10982202e-01j
#    3.60090964e+03-2.26601768e-01j  6.42014733e+01-1.31056740e-02j
#    7.25306141e+02+4.70042376e-01j -1.80062161e+03-1.31443529e-01j
#   -8.83147135e+02-4.28225204e-02j -1.64971351e+03-1.39282749e-01j
#    3.75671378e+01-8.75535259e-04j]
#  [-3.49191374e+04+8.63147984e-01j  1.53907241e+03+7.74919727e-02j
#   -3.13811281e+03-6.01434342e-01j -5.91251564e+04-1.68762562e+00j
#    8.65101440e+03-1.90195165e-03j -9.48345601e+03-1.45279914e+00j
#   -1.91391502e+04+3.19212902e-01j  1.33178106e+04+9.42906417e-02j
#   -6.26999289e+04-2.62526653e+00j  1.33756344e+04+1.74854902e-01j
#   -9.09964797e+02+1.44266439e-01j  2.00938061e+03+1.00521343e+00j
#    1.94025831e+03+4.21472282e-02j]
#  [-8.19010312e+04-2.85210122e+00j  7.60805124e+02-3.30649130e-03j
#    2.87001474e+04+1.30181385e+00j  2.21481024e+04+1.25478583e+00j
#    5.11818629e+03+1.25522522e-01j  2.78516127e+04+1.51478581e+00j
#    1.94991307e+04-1.34574777e+00j -2.80406309e+03-6.24011071e-02j
#    3.99849687e+04+3.24693399e+00j -1.75191318e+04-6.23402835e-01j
#   -7.35867522e+03-2.81206488e-01j -1.81829306e+04-1.09182238e+00j
#    1.11865677e+02-1.64539979e-02j]
#  [ 8.18941452e+02+2.89059271e-01j -6.42825138e+02+2.46122843e-03j
#   -1.27595746e+03-1.14782798e-01j -5.23626552e+03-1.37290400e-01j
#   -2.33627563e+01-5.78314857e-03j  1.44142916e+03-1.70995267e-01j
#    1.87306545e+03+1.24941836e-01j  7.88297402e+02+1.91420354e-02j
#   -4.54112587e+02-3.90539613e-01j  5.36619387e+03+7.78496080e-02j
#    8.62810418e+01+2.71976656e-02j -1.24175068e+03+1.08107992e-01j
#    6.90152123e+01+3.09634723e-03j]
#  [ 2.70847310e+04+1.36678126e+00j -1.73942027e+03-1.01949752e-02j
#   -9.32061914e+03-5.09644507e-01j -7.29082693e+03-3.31618977e-01j
#   -2.69743784e+03-5.66665387e-02j -2.04151054e+03-5.65312073e-01j
#   -7.38282924e+02+6.15075841e-01j  2.74515868e+02+3.92931962e-02j
#    6.14624212e+02-1.30286458e+00j  1.29184417e+04+3.42380412e-01j
#    2.15331134e+03+1.17286879e-01j  1.44076106e+03+3.73400715e-01j
#   -2.29853710e+02+3.34655470e-03j]
#  [-3.24785775e+05+7.71571088e+00j  1.71261084e+04-1.85749144e-01j
#    6.81431137e+04-6.76870347e-01j -7.07805381e+04-3.45335468e-01j
#    3.61830236e+04-7.03486238e-01j  3.86636351e+04-3.75004901e+00j
#   -2.34813727e+05+5.41314982e+00j  2.52746236e+04-2.54908128e-01j
#    1.74378613e+04-4.65616277e+00j -1.05880505e+05+2.96816412e+00j
#   -1.96496040e+04+4.82348757e-01j -2.84326609e+04+1.99616866e+00j
#    1.85794215e+02-6.85183006e-02j]]

# %%
# np.linalg.eigvals(bop_plasma_A_matrix)
np.linalg.matrix_rank(bop_plasma_A_matrix)
# Out:
# 5

# %% [markdown]
# ## The next few cells will be devoted to making plots from a simulation of the LQG feedback loop

# %%
lqr_outputs = loadmat('data/plotting_data/LQG_model_data/LQR_outputs').get('LQR_outputs')
L2_current_flux_1_lqg = loadmat('data/plotting_data/LQG_model_data/L2_current_flux_1').get('L2_current_flux_1')
desired_L2_current_flux_1_lqg = loadmat('data/plotting_data/LQG_model_data/desired_L2_current_flux_1').get('desired_L2_flux_1')

# %%
plt.figure()
lqg_time = np.linspace(0,.002,len(lqr_outputs))
# Plot the time series with a readable color scheme and markers
plt.figure(figsize=(10, 6))

plt.plot(lqg_time, lqr_outputs[:,1], label='LQR outputs', color='red', linewidth=1.5)

# Add legend, title, and labels with larger font size
plt.legend(fontsize=23,loc = 'upper right')
plt.title('', fontsize='xx-large')
plt.xlabel('Time (seconds)', fontsize=30)
plt.ylabel('Voltage', fontsize=30)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)

# Set x-axis limits to zoom in between 0.002 and 0.0021 seconds


# Show the plot
plt.savefig(f'LQR outputs ',bbox_inches="tight")
plt.show()

# %%
plt.figure()

# Plot the time series with a readable color scheme and markers
plt.figure(figsize=(10, 6))



plt.plot(lqg_time, desired_L2_current_flux_1_lqg, label='Desired Waveform', color='black', marker='o', markersize=1, linewidth=.5)

plt.plot(lqg_time, L2_current_flux_1_lqg , label='L2 current flux 1', color='red', linewidth=1.5)
# Add legend, title, and labels with larger font size
plt.legend(fontsize='x-small',loc = 'upper right')
plt.title('', fontsize='xx-large')
plt.xlabel('Time (seconds)', fontsize=30)
plt.ylabel('Current (A)', fontsize=30)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)

# Set x-axis limits to zoom in between 0.002 and 0.0021 seconds


# Show the plot
plt.savefig(f'Desired vs measured L2 current LQG',bbox_inches="tight")
plt.show()

# %%
def load_shot(directory,flux,plasma): #Pass in a directory as a string, and this function will cycle through the whole directory 
                             
    '''
    This function takes a file path and looks for .mat files containing the data from the HIT-SIU circuits. The function will
    cycle through the directory and pick out these files, and return lists of the circuit data configured in a specific order.
    
    parameters:
    directory: string. file path to desired .mat files to be loaded in.
    flux: bool. Determine if shot being loaded needs to look for flux circuit or voltage circuit variable names
    plasma: bool. Determine if toroidal plasma current ('i_tor') should be included in the time series
    '''   
        
    data_list = []
    for i in os.listdir(directory):
        if 'mat' in i:
            data_list.append(loadmat(f"{directory}/{i}"))

    # data_list.append(loadmat('data/vacuum_shots_220705_220707/220707001'))
    input_list = []
    state_list = []

    experiment_time = data_list[0].get('time')    
    experiment_time = experiment_time.reshape(len(experiment_time)) #reshape the time vector to a 0d array


#     data = loadmat('data/shot_220816005_data.mat')
#     vals = data['shot_220816005']
#     vals = vals[:,:]

#     voltage1 = vals[:,1]
#     voltage2 = vals[:,2]
#     voltage3 = vals[:,3]
#     voltage4 = vals[:,4]

    trajectory_list = []
    inputs_list = []
    state_deriv_list = []
    
    if flux == True:

        state_order = ['i_L1_1','v_cap_1','i_fcoil_1','i_L1_2','v_cap_2','i_fcoil_2','i_L1_3','v_cap_3','i_fcoil_3','i_L1_4','v_cap_4','i_fcoil_4']
        state_deriv_order = ['v_L1_1','i_cap_1','v_fcoil_1','v_L1_2','i_cap_2','v_fcoil_2','v_L1_3','i_cap_3','v_fcoil_3','v_L1_4','i_cap_4','v_fcoil_4']
    
    else:
        state_order = ['i_L1_1','v_cap_1','i_vcoil_1','i_L1_2','v_cap_2','i_vcoil_2','i_L1_3','v_cap_3','i_vcoil_3','i_L1_4','v_cap_4','i_vcoil_4']
        state_deriv_order = ['v_L1_1','i_cap_1','v_vcoil_1','v_L1_2','i_cap_2','v_vcoil_2','v_L1_3','i_cap_3','v_vcoil_3','v_L1_4','i_cap_4','v_vcoil_4']
    inputs_order = ['v_spa_1','v_spa_2','v_spa_3','v_spa_4']
    
    
    if plasma == True:
        state_order.append('i_tor')
        
        
    state_dict = dict.fromkeys(state_order)
    state_deriv_dict = dict.fromkeys(state_deriv_order)
    inputs_dict = dict.fromkeys(inputs_order)

    for d in data_list:

        for k,v in d.items():
            if k in state_dict:
                state_dict[k] = v
            if k in state_deriv_dict:
                state_deriv_dict[k] = v
            if k in inputs_dict:
                inputs_dict[k] = v


        trajectory_list.append(np.asarray(list(state_dict.values())).T)
        inputs_list.append(np.asarray(list((inputs_dict.values()))).T)
        state_deriv_list.append((np.asarray(list(state_deriv_dict.values())).T))




    for i in range(len(trajectory_list)):
        trajectory_list[i] = trajectory_list[i][0,:,:]
        inputs_list[i] = inputs_list[i][0,:,:]
        state_deriv_list[i] = state_deriv_list[i][0,:,:]

    return trajectory_list,inputs_list,state_deriv_list, experiment_time

# %%
directory = "data/vacuum_shots_220816/good_shots"
trajectory_list,inputs_list,state_deriv_list,experiment_time = load_shot(directory, flux = True, plasma = False) #Flux circuits in vacuum

flux_trajectory_list,flux_inputs_list,flux_state_deriv_list,experiment_time = load_shot('data/plasma_shots/flux_data/220816009',flux = True,plasma = True)

new_plasma_shot_list,new_plasma_shot_inputs_list,new_plasma_shot_state_deriv_list,new_plasma_shot_time = load_shot('data/plasma_shots/flux_data/220816008',flux=True,plasma=True)

print(np.shape(new_plasma_shot_list[0]))

print(np.shape(flux_trajectory_list[0]))
# Out:
# (2256, 13)
# (2256, 13)

# %%
np.linalg.eigvals(sysc.A)
# Out:
# array([-5374.04778628+1.28310868e+05j, -5374.04778628-1.28310868e+05j,
#        -6150.9991369 +1.38653663e+05j, -6150.9991369 -1.38653663e+05j,
#        -6044.96267505+1.37273047e+05j, -6044.96267505-1.37273047e+05j,
#        -6044.96265218+1.37273047e+05j, -6044.96265218-1.37273047e+05j,
#        -2052.57854051+0.00000000e+00j, -2915.80449147+3.07306116e-05j,
#        -2915.80449147-3.07306116e-05j, -2983.64806906+0.00000000e+00j])

# %%
train = flux_trajectory_list[0][2256-484::,:].T
print(np.shape(train))



[t,y,xout_opt] = lsim((opt_A,B,C,D),inputs_list[2][251::,:],experiment_time[251::])
[t,y,xout_bop_plasma] = lsim((bop_plasma_A_matrix,B_13,C_13,D),flux_inputs_list[0][251::,:],experiment_time[251::])

[t,y,xout_bop_plasma_new_shot] = lsim((bop_plasma_A_matrix,B_13,C_13,D),new_plasma_shot_inputs_list[0][251::,:],experiment_time[251::])
# Out:
# (13, 484)

# %%
# Assuming experiment_time contains time values in seconds
# Convert seconds to milliseconds for the x-axis
experiment_time_ms = [t * 1000 for t in experiment_time]

plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.grid(color='white')
plt.plot(experiment_time_ms[251:], flux_inputs_list[0][251:, :], 'r')
plt.xlabel('Time (ms)', fontsize=30)
plt.ylabel('Voltage (V)', fontsize=30)
plt.legend(['SPA Voltage'], fontsize = 25)
plt.xlim([1.5, 1.8])  # Adjusted xlim for milliseconds
plt.xticks(fontsize=25)
plt.yticks(fontsize = 25)
plt.rcParams['savefig.facecolor'] = 'white'
plt.savefig('SPA voltage of an experimental shot', bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Plots of the flux circuits during a vacuum shot

# %%
[t,y,xout_sim] = lsim(sysc, inputs_list[2][251::],experiment_time[251::])
row = 'L2'
make_row_graph([trajectory_list[2][251::,:],xout_sim],"",
           ['shot 220816005','Analytic Model'],False, experiment_time[251::],row)
    
xout_train = trajectory_list[2][1772::,:]
tout_train = experiment_time[1772::].reshape(len(experiment_time[1772::]))



print(np.shape(xout_train.T))

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'analytic vs experimental data {row}',bbox_inches="tight")
# Out:
# (12, 484)

# %%
[t,y,xout_sim] = lsim(sysc, flux_inputs_list[0][251::],experiment_time[251::])
row = 'L2'
make_row_graph([flux_trajectory_list[0][251::,:],xout_sim],"",
           ['shot 220816009','Analytic Model'],False, experiment_time[251::],row, plasma = True)
    
xout_train = trajectory_list[2][1772::,:]
tout_train = experiment_time[1772::].reshape(len(experiment_time[1772::]))



print(np.shape(xout_train.T))

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'analytic vs plasma data {row}',bbox_inches="tight")
# Out:
# (12, 484)

# %%
print(np.shape(xout_sim[1000:1100,:]))
print(np.shape(trajectory_list[2][1251:1351,:]))
# Out:
# (100, 12)
# (100, 12)

# %%
[t,y,xout_sim] = lsim(sysc, inputs_list[2][251::],experiment_time[251::])
row = 'L2'
make_row_graph([trajectory_list[2][1251:1351,:], xout_sim[1000:1100,:] ],"",
           ['shot 220816005','Analytic Model'],False, experiment_time[1251:1351],row)
    
xout_train = trajectory_list[2][1772::,:]
tout_train = experiment_time[1772::].reshape(len(experiment_time[1772::]))
plt.xlim([experiment_time[1251]*1000,experiment_time[1351]*1000])


print(np.shape(xout_train.T))

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'analytic vs experimental data zoomed in {row}',bbox_inches="tight")
# Out:
# (12, 484)

# %%
print(np.linalg.eigvals(sysc.A))
# Out:
# [-5374.04778628+1.28310868e+05j -5374.04778628-1.28310868e+05j
#  -6150.9991369 +1.38653663e+05j -6150.9991369 -1.38653663e+05j
#  -6044.96267505+1.37273047e+05j -6044.96267505-1.37273047e+05j
#  -6044.96265218+1.37273047e+05j -6044.96265218-1.37273047e+05j
#  -2052.57854051+0.00000000e+00j -2915.80449147+3.07306116e-05j
#  -2915.80449147-3.07306116e-05j -2983.64806906+0.00000000e+00j]

# %%
row = 'L2'
make_row_graph([flux_trajectory_list[0][251::,:],bop_on_plasma],"",
           ['shot 220816009','BOP-DMD'],False, experiment_time[251::],row, plasma= True)
    
xout_train = trajectory_list[2][1772::,:]
tout_train = experiment_time[1772::].reshape(len(experiment_time[1772::]))



print(np.shape(xout_train.T))

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'BOP-DMD on plasma data {row}',bbox_inches="tight")
# Out:
# (12, 484)

# %%
plt.figure()
bop_A_plasma_eigs = np.linalg.eigvals(bop_plasma_A_matrix)
analytic_eigs = np.linalg.eigvals(sysc.A)
plt.scatter(bop_A_plasma_eigs.real,bop_A_plasma_eigs.imag)
plt.scatter(analytic_eigs.real,analytic_eigs.imag)
plt.legend(['BOP eigs','Analytic model eigs'])

# %%
print(np.shape(sysc.A))
# Out:
# (12, 12)

# %%
bop_A_plasma_eigs_err_real = bop_plasma_A_matrix_eig_variance[4::,0]
bop_A_plasma_eigs_err_imag = bop_plasma_A_matrix_eig_variance[4::,1]

# %%
print(bop_A_plasma_eigs[0:5])
# Out:
# [-11643.44977486-1.16993961e+05j -11644.00582652+1.16993213e+05j
#  -17529.26238718-5.62502797e+04j -17528.65337586+5.62503070e+04j
#   -8557.26485571+2.11343030e-03j]

# %%
print(bop_A_plasma_eigs_err_real[0])
# Out:
# 2.229034071721843e-22

# %%
plt.figure(figsize = (12,12))
bop_A_plasma_eigs = np.linalg.eigvals(bop_plasma_A_matrix)[0:5]
analytic_eigs = np.linalg.eigvals(A_plasma)
plt.errorbar(bop_A_plasma_eigs.real, bop_A_plasma_eigs.imag / (1000 * 2 * np.pi),
             xerr=bop_A_plasma_eigs_err_real,
             yerr=bop_A_plasma_eigs_err_imag / (1000 * 2 * np.pi),
             fmt='o', markersize=17, label='BOP eigs', alpha=1, capsize=5)

plt.scatter(analytic_eigs.real,analytic_eigs.imag/(1000*2*np.pi), s = 240, color = '#ff7f0e')

plt.legend(['BOP eigs','Analytic model eigs'], fontsize = 22, loc = 'best')
plt.xlabel('real', size = 33)
plt.ylabel('imaginary (kHz)', size = 33)
plt.xlim(right = -1000)
plt.xticks(fontsize = 25 )
plt.yticks(fontsize = 25)
plt.rcParams['savefig.facecolor']='white'
plt.savefig('eigenvalues of BOP plasma vs analytic plasma',bbox_inches="tight")

# %%
bop_A_plasma_eigs
# Out:
# array([-1.16434498e+04-1.16993961e+05j, -1.16440058e+04+1.16993213e+05j,
#        -1.75292624e+04-5.62502797e+04j, -1.75286534e+04+5.62503070e+04j,
#        -8.55726486e+03+2.11343030e-03j,  7.83051894e-12-9.27863492e-13j,
#        -7.91691182e-12-3.37769398e-12j, -8.46557903e-12+2.46157537e-12j,
#        -6.82749854e-12+1.00710885e-12j,  2.51096697e-12+1.96384205e-12j,
#         2.44958136e-12+2.93965137e-14j, -5.89251973e-13+2.47511371e-13j,
#         1.62908092e-13-6.13736690e-14j])

# %%
print(bop_A_plasma_eigs)
# Out:
# [-1.16434498e+04-1.16993961e+05j -1.16440058e+04+1.16993213e+05j
#  -1.75292624e+04-5.62502797e+04j -1.75286534e+04+5.62503070e+04j
#  -8.55726486e+03+2.11343030e-03j  7.83051894e-12-9.27863492e-13j
#  -7.91691182e-12-3.37769398e-12j -8.46557903e-12+2.46157537e-12j
#  -6.82749854e-12+1.00710885e-12j  2.51096697e-12+1.96384205e-12j
#   2.44958136e-12+2.93965137e-14j -5.89251973e-13+2.47511371e-13j
#   1.62908092e-13-6.13736690e-14j]

# %%
print(analytic_eigs)
# Out:
# [-5398.15077076+128693.74573053j -5398.15077076-128693.74573053j
#  -6164.51182327+138653.06449622j -6164.51182327-138653.06449622j
#  -1856.21605344     +0.j         -2668.42516107     +0.j
#  -3043.64370228     +0.j         -6044.96266362+137273.04653401j
#  -6044.96266362-137273.04653401j -6044.96266362+137273.04653401j
#  -6044.96266362-137273.04653401j -2915.80449147     +0.j
#  -2915.80449147     +0.j        ]

# %%
print(np.shape(xout_bop_plasma_new_shot))
# Out:
# (2005, 13)

# %%
dotted_line = np.zeros((len(xout_bop_plasma_new_shot)))


row = 'L2'
make_row_graph([new_plasma_shot_list[0][251::,:],xout_bop_plasma_new_shot],'',['220816008','BOP-DMD'],
               False,new_plasma_shot_time[251::],row, plasma = True)

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'BOP on new plasma shot {row}',bbox_inches="tight")

# %% [markdown]
# ## BOP-DMD cannot disambiguate actuation and dynamics, so we train on the last millisecond of a shot when the power supplies have turned off and the circuits are ringing down

# %%
rms_opt = mean_squared_error(trajectory_list[2][251::,:].real, xout_opt.real, squared=False)
rms_analytic = mean_squared_error(trajectory_list[2][251::,:].real, xout_sim, squared=False)
print(rms_opt)
print(rms_analytic)
# Out:
# 99.02469785659616
# 891.6201636152604

# %%
bop_on_vacuum_data = loadmat('data/bop_on_vacuum_data_220816005').get('xout_bop')
row = 'L2'
make_row_graph([trajectory_list[2][251::,:],bop_on_vacuum_data.T],"",
           ['shot 220816005','BOP-DMD'],False, experiment_time[251::],row)

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'BOP on vacuum data {row}',bbox_inches="tight")

# %%
[t,y,xout_bop_220816004] = lsim((bop_A_vacuum,B,C,D),inputs_list[1][251::,:],experiment_time[251::])

make_row_graph([trajectory_list[1][251::,:],xout_bop_220816004],"",
           ['shot 220816004','BOP-DMD'],False, experiment_time[251::],'L2')

plt.rcParams['savefig.facecolor']='white'
plt.savefig(f'BOP-dmd vs new experimental data {row}',bbox_inches="tight")

# %%
df = pd.DataFrame(np.random.random((10,10,)))
plt.rcParams['text.color'] = 'k'
plt.rcParams['savefig.facecolor']='white'
Fontdict = {'fontsize': 30}
A_aug = np.zeros((13,13))
print(np.shape(A_aug))
A_aug[0:12,0:12] = A
vals = [A,opt_A_sim.real]
fig, axn = plt.subplots(2, 1,figsize = (15,10),sharex = True)
cbar_ax = fig.add_axes([.91, .3, .03, .4])
# (figsize = (20,15))
titles = ['Vacuum State Space','OPT-DMD State Space']
for i, ax in enumerate(axn.flat):
    sns.heatmap(data = vals[i], ax=ax,
                cbar=i == 0,
                cbar_ax=None if i else cbar_ax,vmin = -1e6, vmax = 1e6)
    # Sets title color
    
    ax.set_title(titles[i],fontdict = Fontdict)
    sns.color_palette("Dark2", as_cmap=True)
    sns.set(font_scale=2.8)
fig.tight_layout(rect=[0, 0, .9, 1])
plt.savefig('OPT-DMD heatmap on simulated data',bbox_inches = 'tight')
# Out:
# (13, 13)

# %%
cap_voltage_kf = loadmat('data/plotting_data/Simulink_model_data/Cap_voltage_Kalman_Filter').get('C_Voltage_Approx_Flux_1')
cap_voltage_no_noise = loadmat('data/plotting_data/Simulink_model_data/Cap_voltage_no_noise').get('C_Voltage_No_Noise')
cap_voltage_with_noise = loadmat('data/plotting_data/Simulink_model_data/Cap_voltage_.1_noise_power').get('C_Voltage_Flux_1')


plt.figure()
time = np.linspace(0, 0.004, len(cap_voltage_kf))
# Plot the time series with a readable color scheme and markers
plt.figure(figsize=(10, 6))

plt.plot(time, cap_voltage_with_noise, label='Measured Cap Voltage', color='red', linewidth=1.5)
plt.plot(time, cap_voltage_no_noise, label='True Cap Voltage', color='green', marker='s', markersize=6)
plt.plot(time, cap_voltage_kf, label='Kalman Filter', color='orange', marker='o', markersize=1, linewidth=1)

# Add legend, title, and labels with larger font size
plt.legend(fontsize='xx-small',loc = 'upper right')
plt.title('', fontsize='large')
plt.xlabel('Time (seconds)', fontsize=30)
plt.ylabel('Voltage', fontsize=30)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)

# Set x-axis limits to zoom in between 0.002 and 0.0021 seconds
plt.xlim(0.002, 0.0021)

# Show the plot
plt.savefig(f'Kalman Filter on noisy Cap data',bbox_inches="tight")
plt.show()

# %%
df = pd.DataFrame(np.random.random((10,10,)))
plt.rcParams['text.color'] = 'k'
plt.rcParams['savefig.facecolor']='white'
Fontdict = {'fontsize': 30}
print(np.shape(A_aug))
vals = [A_plasma,bop_plasma_A_matrix.real]
fig, axn = plt.subplots(2, 1,figsize = (15,10),sharex = True)
cbar_ax = fig.add_axes([.91, .3, .03, .4])
# (figsize = (20,15))
titles = ['Analytic Plasma State Space','BOP-DMD State Space']
for i, ax in enumerate(axn.flat):
    sns.heatmap(data = vals[i], ax=ax,
                cbar=i == 0,
                cbar_ax=None if i else cbar_ax,vmin = -1e6, vmax = 1e6)
    # Sets title color
    
    ax.set_title(titles[i],fontdict = Fontdict)
    sns.color_palette("Dark2", as_cmap=True)
    sns.set(font_scale=2.8)
fig.tight_layout(rect=[0, 0, .9, 1])
plt.savefig('BOP-DMD and Analytic Plasma Model heatmap',bbox_inches = 'tight')
# Out:
# (13, 13)

# %% [markdown]
# # Analysis for Matrix norms

# %%
norm_comparison = np.linalg.norm(A_plasma - bop_plasma_A_matrix.real)/np.linalg.norm(A_plasma)

# %%
norm_comparison
# Out:
# 1.008886250799519

# %% [markdown]
# # UQ and Different BOP Trajectories

# %%
A_matrices_BOP_DMD = loadmat('data/Plasma_A_matrices_BOP_DMD.mat').get('atilde_cell_list') #load in all A matrices from a 20 trial run of BOP-DMD

# %%
print(len(A_matrices_BOP_DMD.T))
# Out:
# 20

# %%
bop_trajectory_list = []
plt.figure()
plt.xlabel('Time (ms)', size = 23)
plt.ylabel('Flux Coil Current (A)', size = 23)
plt.xticks(size = 20)
plt.yticks(size = 20)
for k in range(len(A_matrices_BOP_DMD.T)):
    A_mat = A_matrices_BOP_DMD[0,k]
    xout = lsim((A_mat,B_13,C_13,D),flux_inputs_list[0][251::,:],experiment_time[251::])[2]
    bop_trajectory_list.append(xout)
    plt.plot(1000*experiment_time[251::],xout[:,2].real, alpha = .5)

plt.rcParams['savefig.facecolor']='white'
plt.savefig('inidividual bop trajectories L2 flux 1',bbox_inches="tight")

# %%
fig, ax = plt.subplots(nrows=5, ncols=4, sharex=True, sharey = 'row', figsize=(20, 15))
for i in range(len(bop_trajectory_list)):
    plt.subplot(5,4,i+1)
    plt.plot(1000*experiment_time[251::],bop_trajectory_list[i][:,2].real)

# %%
plt.figure()
plt.xlabel('Time (ms)', size = 23)
plt.ylabel('Flux Coil Current (A)', size = 23)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.plot(1000*experiment_time[251::],bop_trajectory_list[0][:,2].real, alpha = .8)
plt.plot(1000*experiment_time[251::],bop_trajectory_list[1][:,2].real, alpha = .8)
plt.plot(1000*experiment_time[251::],bop_trajectory_list[3][:,2].real, alpha = .8)
plt.rcParams['savefig.facecolor']='white'
plt.savefig('bop trajectories 1 2 4 L2 flux 1',bbox_inches="tight")

# %%
print(np.shape(train))

U  = scipy.linalg.svd(train,full_matrices= False)[0]
# Out:
# (13, 484)

# %%
print(np.shape(U))
# Out:
# (13, 13)

# %%
print(np.shape(bop_plasma_A_matrix.real))
U_r = U[:,0:9]
print(np.shape(U_r))
# Out:
# (13, 13)
# (13, 9)

# %%
print(np.shape(U_r.T.conj()))
# Out:
# (9, 13)

# %%
reduced_bop_plasma_A_matrix = U_r.T.conj()@bop_plasma_A_matrix.real@U_r
